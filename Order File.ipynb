# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_column', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_seq_items', None)
pd.set_option('display.max_colwidth', 500)
pd.set_option('expand_frame_repr', True)
import numpy as np
# import csv
# import openpyxl

# %%
# df = pd.read_csv('test.txt',header=None)
# df
# pip install openpyxl

# %% [markdown]
# ## Reading Text File

# %%
df = pd.read_csv('test.txt') # can replace with df = pd.read_table('input.txt') for '\t'

# %% [markdown]
# ## Convert Text File data into Excel File for making it readable py python dataFrame

# %%
df.to_excel('test1.xlsx', 'Sheet1')

# %%
df = pd.read_excel('test1.xlsx')

# %% [markdown]
# ## Showing The Extracted data of Excel file in Python DataFrame

# %%
df
# Out:
#     Unnamed: 0   Case Number Case Type Case Subtype Case File Date  \
# 0            0  221100302272        CV   Debt Claim     08/29/2022
# 1            1  221100302283        CV   Debt Claim     08/29/2022
# 2            2  221100302285        CV   Debt Claim     08/29/2022
# 3            3  221100302347        CV   Debt Claim     08/29/2022
# 4            4  221100302353        CV   Debt Claim     08/29/2022
# 5            5  221100302357        CV   Debt Claim     08/29/2022
# 6            6  221100302367        CV   Debt Claim     08/29/2022
# 7            7  221100302374        CV   Debt Claim     08/29/2022
# 8            8  221100302411        CV   Debt Claim     08/29/2022
# 9            9  221100302421        CV   Debt Claim     08/29/2022
# 10          10  221100302422        CV   Debt Claim     08/29/2022
# 11          11  221100302437        CV   Debt Claim     08/29/2022
# 12          12  221100302439        CV   Debt Claim     08/29/2022
# ...

# %% [markdown]
# ## Eliminating the entries having 'Claim Amount < 3000$' and store the remaining entries in DataFrame

# %%
df = df.loc[df['Claim Amount'] >= 3000.00] 
df
# Out:
#     Unnamed: 0   Case Number Case Type Case Subtype Case File Date  \
# 1            1  221100302283        CV   Debt Claim     08/29/2022
# 3            3  221100302347        CV   Debt Claim     08/29/2022
# 4            4  221100302353        CV   Debt Claim     08/29/2022
# 9            9  221100302421        CV   Debt Claim     08/29/2022
# 10          10  221100302422        CV   Debt Claim     08/29/2022
# 12          12  221100302439        CV   Debt Claim     08/29/2022
# 13          13  221100302440        CV   Debt Claim     08/29/2022
# 15          15  221100302447        CV   Debt Claim     08/29/2022
# 18          18  221100302457        CV   Debt Claim     08/29/2022
# 20          20  221100302473        CV   Debt Claim     08/29/2022
# 23          23  221100302554        CV   Debt Claim     08/30/2022
# 24          24  221100302557        CV   Debt Claim     08/30/2022
# 25          25  221100302560        CV   Debt Claim     08/30/2022
# ...

# %% [markdown]
# ## Store the Updated Entries in 'test1.xlsx' File

# %%
df.to_excel("test1.xlsx")
